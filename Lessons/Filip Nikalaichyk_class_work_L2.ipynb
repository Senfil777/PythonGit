# %%
help(input)
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of ipykernel.ipkernel.IPythonKernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplementedError if active frontend doesn't support stdin.

# %%
name=input('Введи свое имя')
# Out:
# Введи свое имя Петр

# %%
print(name)
# Out:
# Петр

# %%
age=input('Это')
print()
print('Вот')
print(age)
# Out:
# Это 1
# Вот
# 1

# %%
new=int('25')
print(new)
print(type(new))
# Out:
# 25
# <class 'int'>

# %%
number=int(25)
print (number)
print(type(number))
# Out:
# 25
# <class 'int'>

# %%
mix=int(25.5)
print (mix)
print (type(mix))
# Out:
# 25
# <class 'int'>

# %%
price=float(24.51)
print(price)
print(type(price))
# Out:
# 24.51
# <class 'float'>

# %%
x123=float(10)
print(x123)
# Out:
# 10.0

# %%
tem=35
tem=str()
print(tem)
print(type(tem))
# Out:
# <class 'str'>

# %%
#пример

# %%
wee = input('Число: ')
print(type(wee))
# Out:
# Число:  1
# <class 'str'>

# %%
a=int('25')
a1=int(2.8)
a2=int(3)
print(a,isinstance(a, int))
print(a1,isinstance(a1,float))
print(a2,isinstance(a2,str))
# Out:
# 25 True
# 2 False
# 3 False

# %%
user=input('введи имя')
print('Твое имя:',user)
# Out:
# введи имя Фил
# Твое имя: Фил

# %%
user='123'
user = int(user)
print(type(user))
# Out:
# <class 'int'>

# %%
Wl = 10
TxWl=Wl**2
TxWl=str(TxWl)
type(TxWl)
# Out:
# str

# %%
# Проверка пин на корректность
Pin=123
Pin1 = input ('тутт')
Pin1 = int(Pin1)

Pin1 = Pin1**2
print(Pin1)
# Out:
# тутт 2
# 4

# %%
user_pin = input("Введи свой пинкод:")
user_pin = int(user_pin)
user_pin_sq = user_pin ** 2
message = "это твой пинкод в квадрате"
print(message, user_pin_sq)
# Out:
# Введи свой пинкод: 12
# это твой пинкод в квадрате 144

# %%
a, b = 111, 1123
print(f"переменная А {a}, переменная B {b}")
# Out:
# переменная А 111, переменная B 1123

# %%
a, b = 111, 1123

print(f"переменная A {a}, переменная B {b}")
# Out:
# переменная A 111, переменная B 1123

# %%
# * - / + ** // %

#int И int = всегда инт, кроме / (деления)
#int И float = всегда float
#float И int = всегда float
#float И float = всегда float


# если только вы не вызываете функции конструкторы Int float str

# %%
0/7
# Out:
# 0.0

# %%
#Строки

# %%
str = 'Hello'*4

# %%
name= ('cat')
name*3
# Out:
# 'catcatcat'

# %%
name= ('cat')
name2 = name*3
name2*4+name
# Out:
# 'catcatcatcatcatcatcatcatcatcatcatcatcat'

# %%
import keyword

# %%
import keyword


print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
