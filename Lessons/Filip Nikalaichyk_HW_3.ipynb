# %%
li = [1, 2, 3, 4, 5]

# Step 0
print(len(li))

# Step 1
number = int(input("Введи число для замены:"))
li[2] = number

# Step 2
li.pop()

# Step 3
print(len(li))

print(li)
# Out:
# 5
# Введи число для замены: 5
# 4
# [1, 2, 5, 4]
