# %%
import xml

# %%
import xml.etree.ElementTree as et

# %%
my_books_file = et.parse("books.xml")

# %%
root_books = my_books_file.getroot()

# %%
type(root_books)
# Out:
# xml.etree.ElementTree.Element

# %%
root_books [1]
# Out:
# <Element 'book' at 0x000001F0DD9781D0>

# %%
root_books [1].tag
# Out:
# 'book'

# %%
root_books [1].attrib
# Out:
# {'title': 'Hamlet'}

# %%
root_books [1].text
# Out:
# '\n        '

# %%
book1 = root_books[1]

# %%
book1
# Out:
# <Element 'book' at 0x000001F0DD9781D0>

# %%
book1_author = book1[1].text

# %%
root_books.tag
# 'books'

root_books.text
# '\n   '

root_books.tail

root_books.attrib
# {}

# %%
book1_author
# Out:
# '1603'

# %%
for book in root_books:
    print()
    
    book.remove(book.find("author"))
    
    print(book.tag)
    print(book.attrib)
    
    for field in book:
        print("\t", field.tag)
        print("\t\t", field.text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 for book in root_books:
#       2     print()
#       3
# ----> 4     book.remove(book.find("author"))
#       5
#       6     print(book.tag)
#       7     print(book.attrib)
#
# TypeError: remove() argument must be xml.etree.ElementTree.Element, not None

# %%
# Out:
# ['Name', 'Phone']
# ['mother', '222-555-101']
# ['father', '222-555-102']
# ['wife', '222-555-103']
# ['mother-in-law', '222-555-104']

# %%
# Out:
# [repr: Dima, 44, repr: Kate, 34, repr: Deniska, 13, repr: Kot, 14, repr: Sasha, 4, repr: Kate, 55]
# export data
# []
# import data
# [repr: Dima, 44, repr: Kate, 34, repr: Deniska, 13, repr: Kot, 14, repr: Sasha, 4, repr: Kate, 55]
# srt: Dima, 44
