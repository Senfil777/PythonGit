# %%
{
    "users": [
        {
            "id": 1,
            "name": "Dima",
            "age": 12
        },
        {
            "id": 2,
            "name": "Emily",
            "age": 55
        },
        {
            "id": 3,
            "name": "Emil",
            "age": 23
        },
        {
            "id": 4,
            "name": "Lily",
            "age": 2
        }
    ]
}
